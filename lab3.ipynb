# %% [markdown]
# Матвеев С.А.
# прин-368
# Варинт 2: weatherHistory.csv

# %%
import pandas as pd

# Загрузка CSV файла в DataFrame
file_path = 'data/weatherHistory.csv'
data = pd.read_csv(file_path)

# Отображение первых 10 строк данных в таблице
data.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# 3.	Сгенерируйте линейное приближение этих данных. Графически изобразите.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Загрузка данных
data = pd.read_csv('data/weatherHistory.csv')

# Удаление строк с пропущенными значениями (при необходимости)
data = data.dropna(subset=['Temperature (C)', 'Apparent Temperature (C)'])

# Выбор переменных для регрессии
X = data[['Temperature (C)']].values  # Независимая переменная
y = data['Apparent Temperature (C)'].values  # Зависимая переменная

# Создание и обучение модели линейной регрессии
model = LinearRegression()
model.fit(X, y)

# Предсказания на основе модели
y_pred = model.predict(X)

# Оценка модели
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f'MSE: {mse:.2f}')
print(f'R^2: {r2:.2f}')

# Построение графика
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X.flatten(), y=y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Linear fit')
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
plt.title('Linear Regression of Apparent Temperature vs Temperature')
plt.legend()
plt.show()
# Out:
# MSE: 1.68
# R^2: 0.99

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных
data = pd.read_csv('data/weatherHistory.csv')

# Удаление строк с пропущенными значениями (при необходимости)
data = data.dropna(subset=['Temperature (C)', 'Apparent Temperature (C)'])

# Независимая переменная (температура) и зависимая переменная (ощущаемая температура)
x = data['Temperature (C)'].values
y = data['Apparent Temperature (C)'].values

# Вычисление средних значений
x_mean = np.mean(x)
y_mean = np.mean(y)

# Вычисление коэффициента наклона b
numerator = np.mean(x * y) - x_mean * y_mean
denominator = np.mean(x**2) - x_mean**2
b = numerator / denominator

# Вычисление коэффициента a
a = y_mean - b * x_mean

# Предсказание y на основе линейного приближения
y_pred = a + b * x

# Построение графика
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x, y=y, color='blue', label='Actual data')
plt.plot(x, y_pred, color='red', label='Linear fit')
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
plt.title('Linear Approximation of Apparent Temperature vs Temperature')
plt.legend()
plt.show()

print(f'Коэффициент наклона b: {b}')
print(f'Свободный член a: {a}')
# Out:
# Коэффициент наклона b: 1.111652073053155
# Свободный член a: -2.4099578479700696

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных
data = pd.read_csv('data/weatherHistory.csv')

# Удаление строк с пропущенными значениями (при необходимости)
data = data.dropna(subset=['Temperature (C)', 'Apparent Temperature (C)'])

# Независимая переменная (температура) и зависимая переменная (ощущаемая температура)
x = data['Temperature (C)'].values
y = data['Apparent Temperature (C)'].values

# Вычисление средних значений
x_mean = np.mean(x)
y_mean = np.mean(y)

# Вычисление коэффициента наклона b
numerator = np.mean(x * y) - x_mean * y_mean
denominator = np.mean(x**2) - x_mean**2
b = numerator / denominator

# Вычисление свободного члена a
a = y_mean - b * x_mean

# Предсказание y на основе линейного приближения
y_pred = a + b * x

# Построение графика
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x, y=y, color='blue', label='Actual data')
plt.plot(x, y_pred, color='red', label='Linear fit')
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
plt.title('Linear Approximation of Apparent Temperature vs Temperature')
plt.legend()
plt.show()

print(f'Коэффициент наклона b: {b}')
print(f'Свободный член a: {a}')
# Out:
# Коэффициент наклона b: 1.111652073053155
# Свободный член a: -2.4099578479700696

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# Загрузка данных
data = pd.read_csv('data/weatherHistory.csv')

# Используем столбцы 'Temperature (C)' и 'Apparent Temperature (C)' для линейной регрессии
X = data['Temperature (C)'].values.reshape(-1, 1)  # Признак
y = data['Apparent Temperature (C)'].values  # Целевая переменная

# Создаем и обучаем модель линейной регрессии
model = LinearRegression()
model.fit(X, y)

# Предсказания модели
y_pred = model.predict(X)

# Вычисляем среднеквадратичную ошибку
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error:", mse)

# Визуализация результатов
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X.flatten(), y=y, color='blue', label='Actual Data')
sns.lineplot(x=X.flatten(), y=y_pred, color='red', label='Linear Approximation')
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
plt.title('Linear Approximation of Temperature Data')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 1.680681953258282

# %% [markdown]
# Задание 4: Рассчитайте линейный коэффициент корреляции:
#
# ![image.png](attachment:image.png)
